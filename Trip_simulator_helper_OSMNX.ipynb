# %%
import osmnx as ox

# %%
G = ox.graph_from_place('Manhattan Island, New York City, New York, USA', network_type='drive')
ox.plot_graph(G)
# Out:
# (<Figure size 264.493x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f9e3a0779e8>)

# %%
G = ox.graph_from_place('Piedmont, California, USA', network_type='drive')

# %%
# https://github.com/mocnik-science/osm-python-tools

# %%
from OSMPythonTools.api import Api
api = Api()

# %%
way = api.query('way/5887599')
# Out:
# [api] downloading data: way/5887599

# %%
way.tag('building')
# Out:
# 'castle'

# %%
way.tag('architect')
# Out:
# 'Johann Lucas von Hildebrandt'

# %%
way.tag('website')
# Out:
# 'https://www.belvedere.at/'

# %%
way.tag('country')

# %%
import openrouteservice
coords = ((8.34234,48.23424),(8.34423,48.26424))

# %%
client = openrouteservice.Client(key='5b3ce3597851110001cf624892badc35488242279efc4aafa66848e7') # Specify your personal API key
routes = client.directions(coords)

# %%
print (routes)
# Out:
# {'routes': [{'summary': {'distance': 5510.5, 'duration': 810.6}, 'segments': [{'distance': 5510.5, 'duration': 810.6, 'steps': [{'distance': 255.0, 'duration': 61.2, 'type': 11, 'instruction': 'Head south on Benatweg', 'name': 'Benatweg', 'way_points': [0, 9]}, {'distance': 52.4, 'duration': 12.6, 'type': 6, 'instruction': 'Continue straight onto Benatweg', 'name': 'Benatweg', 'way_points': [9, 12]}, {'distance': 1688.7, 'duration': 135.1, 'type': 1, 'instruction': 'Turn right onto Hölzle, K 5528', 'name': 'Hölzle, K 5528', 'way_points': [12, 63]}, {'distance': 265.2, 'duration': 31.8, 'type': 13, 'instruction': 'Keep right', 'name': '-', 'way_points': [63, 71]}, {'distance': 302.8, 'duration': 36.3, 'type': 0, 'instruction': 'Turn left', 'name': '-', 'way_points': [71, 80]}, {'distance': 536.7, 'duration': 64.4, 'type': 0, 'instruction': 'Turn left', 'name': '-', 'way_points': [80, 92]}, {'distance': 247.6, 'duration': 29.7, 'type': 13, 'instruction': 'Keep right', 'name': '-', 'way
# ...

# %%
from openrouteservice.directions import directions
routes = directions(client, coords, maneuvers=True)

# %%
print (routes)
# Out:
# {'bbox': [8.327707, 48.231946, 8.345244, 48.263552], 'routes': [{'summary': {'distance': 5510.5, 'duration': 810.6}, 'segments': [{'distance': 5510.5, 'duration': 810.6, 'steps': [{'distance': 255.0, 'duration': 61.2, 'type': 11, 'instruction': 'Head south on Benatweg', 'name': 'Benatweg', 'way_points': [0, 9], 'maneuver': {'location': [8.344267867749956, 48.233825673919], 'bearing_before': 0, 'bearing_after': 194}}, {'distance': 52.4, 'duration': 12.6, 'type': 6, 'instruction': 'Continue straight onto Benatweg', 'name': 'Benatweg', 'way_points': [9, 12], 'maneuver': {'location': [8.342327550254632, 48.232158979002214], 'bearing_before': 252, 'bearing_after': 250}}, {'distance': 1688.7, 'duration': 135.1, 'type': 1, 'instruction': 'Turn right onto Hölzle, K 5528', 'name': 'Hölzle, K 5528', 'way_points': [12, 63], 'maneuver': {'location': [8.341711014696457, 48.23194589239238], 'bearing_before': 225, 'bearing_after': 298}}, {'distance': 265.2, 'duration': 31.8, 'type': 13, 'instructio
# ...

# %%
import urllib2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-846c1dbd158b> in <module>
# ----> 1 import urllib2
#
# ModuleNotFoundError: No module named 'urllib2'

# %%
from urllib2 import Request, urlopen
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-24-d44f42a3ef6f> in <module>
# ----> 1 from urllib2 import Request, urlopen
#
# ModuleNotFoundError: No module named 'urllib2'

# %%
from urllib2 import Request, urlopen

headers = {
  'Accept': 'application/json; charset=utf-8'
}
request = Request('https://api.openrouteservice.org/v2/directions/driving-car?api_key=5b3ce3597851110001cf624892badc35488242279efc4aafa66848e7&start=8.681495,49.41461&end=8.687872,49.420318', headers=headers)

response_body = urlopen(request).read()
print response_body

# %%
import  geopy

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim()
location = geolocator.reverse("48.8588443, 2.2943506")

print(location.address)
# Out:
# /opt/anaconda3/envs/ipy_osmnx/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
# Champ de Mars, Place Jacques Rueff, Gros-Caillou, 7e, Paris, Île-de-France, France métropolitaine, 75007, France

# %%
import geocoder

g = geocoder.osm([53.5343609, -113.5065084], method='reverse')
print (g.json['city']) # Prints Edmonton

g = geocoder.osm('Edmonton, Canada')
print (g.json['lat'], g.json['lng']) # Prints 53.5343609, -113.5065084
# Out:
# Edmonton
# 53.535411 -113.507996

# %%
g = geocoder.osm('Ontario, Canada')
print (g.json['lat'], g.json['lng'])
# Out:
# 50.000678 -86.000977

# %%
g = geocoder.osm('Toronto, Canada')
print (g.json['lat'], g.json['lng'])
# Out:
# 43.653963 -79.387207

# %%
g = geocoder.osm('Toronto, Canada')
print (g.json['lat'], g.json['lng'])
# Out:
# 43.2425289 -79.9470423

# %%
import requests
import geocoder
g = geocoder.osm('Mountain View, CA')
print (g.latlng)
g = geocoder.google("Ottawa")
print(g.bbox)
url = 'https://maps.googleapis.com/maps/api/geocode/json'
params = {'sensor': 'false', 'address': 'Mountain View, CA'}
r = requests.get(url, params=params)
results = r.json()['results']
#location = results['geometry']['location']
#print(location['lat'], location['lng'])
# Out:
# [45.5073725, -73.6050824]
# None

# %%
import requests
import geocoder
g = geocoder.osm('Munich, DE')
print (g.latlng)
# Out:
# [48.1371079, 11.5753822]

# %%
import requests
import geocoder
g = geocoder.osm('Brasov')
print (g.latlng)
# Out:
# [45.6523093, 25.6102746]

# %%
g = geocoder.osm('Bremen, DE')
g.json
# Out:
# {'accuracy': 0.8730364577779981,
#  'address': 'Bremen, Deutschland',
#  'bbox': {'northeast': [53.5984187, 8.9907318],
#   'southwest': [53.0110367, 8.4815929]},
#  'confidence': 1,
#  'country': 'Deutschland',
#  'country_code': 'de',
#  'county': 'Bremen',
#  'icon': 'https://nominatim.openstreetmap.org/images/mapicons/poi_place_city.p.20.png',
#  'importance': 0.8730364577779981,
#  'lat': 53.0758196,
#  'lng': 8.8071646,
#  'ok': True,
#  'osm_id': 62559,
#  'osm_type': 'relation',
#  'place_id': 197692829,
#  'place_rank': 16,
#  'quality': 'city',
#  'raw': {'place_id': 197692829,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 62559,
#   'boundingbox': ['53.0110367', '53.5984187', '8.4815929', '8.9907318'],
#   'lat': '53.0758196',
#   'lon': '8.8071646',
#   'display_name': 'Bremen, Deutschland',
#   'place_rank': 16,
#   'category': 'place',
#   'type': 'city',
# ...
